# %%
% matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.title("Your id")
plt.plot([1, 3, 2, 4])

# %%
# define a customered x axis
x = range(6)
plt.plot(x, [i ** 2 for i in x])

# %%
x = np.arange(0.0, 0.6, 0.01)
#x = np.linspace(0.0, 0.6, 61)
y = [i ** 2 for i in x]
plt.plot(x, y)

# %%
x = np.linspace(-np.pi, np.pi, 256)
sinx = np.sin(x)
cosx = np.cos(x)
plt.plot(x, sinx)   # plot at the same graph
plt.plot(x, cosx)
plt.title("Jie")
# Out:
# Text(0.5,1,'Jie')

# %%
plt.plot(x, sinx, x, cosx)

# %%
plt.plot(x, sinx, x, cosx)
plt.grid(True)

# %%
x = np.arange(1, 5)
plt.plot(x, x * 1.5, x, x* 3.0, x, x/2.0)
plt.grid(True)
plt.title("jie dao ci yi you")
# Out:
# Text(0.5,1,'jie dao ci yi you')

# %%
x = np.arange(1, 5)
plt.plot(x, x * 1.5, x, x* 3.0, x, x/2.0)
plt.grid(True)
plt.axis([0, 5, -1, 13])   # set the (xaxis start, end, yaxisstart, end)
plt.title("jie dao ci yi you")
# Out:
# Text(0.5,1,'jie dao ci yi you')

# %%
x = np.arange(1, 5)
plt.plot(x, x * 1.5, x, x* 3.0, x, x/2.0)
plt.grid(True)
plt.axis([2, 3, 0, 10])
# Out:
# [2, 3, 0, 10]

# %%
x = np.arange(1, 5)
plt.plot(x, x * 1.5, x, x* 3.0, x, x/2.0)
plt.grid(True)
plt.axis([2, 3, 0, 10]) 
plt.xlim([0, 5])           # limit only x axis
plt.ylim([-1, 13])         # limit only y axis
plt.title("jie dao ci yi you")
# Out:
# Text(0.5,1,'jie dao ci yi you')

# %%
x = np.arange(1, 5)

plt.plot(x, x * 1.5, label = "map1")    # create the label
plt.plot(x, x * 3.0, label = "map2")
plt.plot(x, x / 2.0, label = "map3")


plt.grid(True)

plt.axis([2, 3, 0, 10]) 

plt.xlim([0, 5])
plt.ylim([-1, 13])

plt.title(" This is a map ")
plt.xlabel(" xaxis label")
plt.ylabel(" yaxis label")

plt.legend()                        # use plt.legend() to show the label

# %%
x = np.arange(1, 5)

plt.plot(x, x * 1.5, label = "map1")
plt.plot(x, x * 3.0, label = "map2")
plt.plot(x, x / 2.0, label = "map3")


plt.grid(True)

plt.axis([2, 3, 0, 10]) 

plt.xlim([0, 5])
plt.ylim([-1, 13])

plt.title(" This is a map ")
plt.xlabel(" xaxis label")
plt.ylabel(" yaxis label")

plt.legend(loc = (0.5, 0.5))    # show the lengend in a particular location

# %%
x = np.arange(1, 5)

# add more arguments to change the color line width and linestyle
plt.plot(x, x * 1.5, label = "map1", color = "red",   linewidth = 1.0, linestyle="-")
plt.plot(x, x * 3.0, label = "map2", color = "green", linewidth = 2.0, linestyle=":")
plt.plot(x, x / 2.0, label = "map3", color = "blue",  linewidth = 3.0, linestyle =":")


plt.grid(True)

plt.axis([2, 3, 0, 10]) 

plt.xlim([0, 5])
plt.ylim([-1, 13])

plt.title(" This is a map ")
plt.xlabel(" xaxis label")
plt.ylabel(" yaxis label")

plt.legend(loc = (0.5, 0.5))

# %%
x = np.arange(1, 5)

plt.plot(x, x * 1.5, label = "map1", color = "red",   linewidth = 1.0, linestyle="-")
plt.plot(x, x * 3.0, label = "map2", color = "green", linewidth = 2.0, linestyle=":")
plt.plot(x, x / 2.0, label = "map3", color = "blue",  linewidth = 3.0, linestyle =":")


plt.grid(True)

plt.axis([2, 3, 0, 10]) 

plt.xlim([0, 5])
plt.ylim([-1, 13])

plt.title(" This is a map ")
plt.xlabel(" xaxis label")
plt.ylabel(" yaxis label")

plt.legend(loc = (0.5, 0.5)) 

# add customered line points
plt.xticks([1.1, 1.6, 2.1, 2.6, 3.1, 3.6, 4.1, 4.6, 5.1])
plt.yticks([1, 3, 5, 7, 9, 11, 13])
# Out:
# ([<matplotlib.axis.YTick at 0x11ead38d0>,
# ...
#  <a list of 7 Text yticklabel objects>)

# %%
x = np.linspace(-np.pi, np.pi, 256)
sin_y = np.sin(x)
cos_y = np.cos(x)
plt.plot(x, sin_y, label="Sin")
plt.plot(x, cos_y, label="cos")
plt.legend()
#latex的语法
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1,0,1],
          [r'$-1$', r'$0$', r'$+1$'])
# Out:
# ([<matplotlib.axis.YTick at 0x110be6c18>,
# ...
#  <a list of 3 Text yticklabel objects>)

# %%
# multiple graph in one
# plt.subplot ( # of rows, # of columns, position)

# %%
plt.subplot(2,1,1)   # set the position
x = np.arange(1, 5)

plt.plot(x, x * 1.5, label = "map1", color = "red",   linewidth = 1.0, linestyle="-")
plt.plot(x, x * 3.0, label = "map2", color = "green", linewidth = 2.0, linestyle=":")
plt.plot(x, x / 2.0, label = "map3", color = "blue",  linewidth = 3.0, linestyle =":")


plt.grid(True)

plt.axis([2, 3, 0, 10]) 

plt.xlim([0, 5])
plt.ylim([-1, 13])

plt.title(" This is a map ")
plt.xlabel(" xaxis label")
plt.ylabel(" yaxis label")

plt.legend(loc = (0.5, 0.5)) 

# add custommered line points
plt.xticks([1.1, 1.6, 2.1, 2.6, 3.1, 3.6, 4.1, 4.6, 5.1])
plt.yticks([1, 3, 5, 7, 9, 11, 13])


plt.subplot(2,1,2) # set the position
x = np.linspace(-np.pi, np.pi, 256)
sin_y = np.sin(x)
cos_y = np.cos(x)
plt.plot(x, sin_y, label="Sin")
plt.plot(x, cos_y, label="cos")
plt.legend()

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1,0,1],
          [r'$-1$', r'$0$', r'$+1$'])

plt.show()

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)

# %%
plt.subplot(2,2,1)
plt.xticks([]), plt.yticks([])    # clear the axis points

plt.subplot(2,2,2)
plt.xticks([]), plt.yticks([])

plt.subplot(2,2,3)
plt.xticks([]), plt.yticks([])

plt.subplot(2,2,4)
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
plt.subplot(2,2,1)
plt.xticks([]), plt.yticks([])   #????? what size do what alpha do
plt.text(0.5, 0.5, "A", ha ="center", va = "center", size = 20, alpha = .5) # add the text in map

plt.subplot(2,2,2)
plt.xticks([]), plt.yticks([])
plt.text(0.5, 0.5, "B", ha ="center", va = "center", size = 20, alpha = .5) # add the text in map

plt.subplot(2,2,3)
plt.xticks([]), plt.yticks([])
plt.text(0.5, 0.5, "C", ha ="center", va = "center", size = 20, alpha = .5) # add the text in map

plt.subplot(2,2,4)
plt.xticks([]), plt.yticks([])
plt.text(0.5, 0.5, "D", ha ="center", va = "center", size = 20, alpha = .5) # add the text in map
# Out:
# Text(0.5,0.5,'D')

# %%
# Statistic graphs

# %%
# plt.hist
# histogram
y = np.random.randn(1000)   # 1000个高斯分布的数
plt.hist(y, 25)             # 分成了25个bar
plt.show()                 # 不用show忽略信息

# %%
x = np.random.randn(1000)
y = 3*x + 4
plt.scatter(x, y)  # ??? what here do
plt.show()

# %%
size = 50 * abs ( np.random.randn(1000))
colors = np.random.randn(1000)
plt.scatter(x, y, s = size, c = colors)    #后面的仅仅是修饰
plt.show()

# %%
# 1st array defines how any bars and their centered location
# 2nd array defines the height of each bar
plt.bar([1,2,3, 4], [4,2,6, 8])  # （ 有这些点， 频率）
plt.show()

# %%
# pie graph
x = 1, 2, 4
labels = ["cat", "dog", "sheep"]
plt.pie(x, labels= labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x11fffe6d8>,
# ...
#  [Text(0.991066,0.477272,'cat'),
#   Text(-0.244773,1.07242,'dog'),
#   Text(-0.244773,-1.07242,'sheep')])

# %%
x = np.arange(0, 4, 0.2)
y = np.exp(-x)
plt.plot(x, y)

# %%
# plt.errorbar

# %%
x = np.arange(0, 4, 0.2)
y = np.exp(-x)
e = 0.1*abs(np.random.randn(len(y)))
plt.errorbar(x,y,yerr = e, fmt = '.-')  # 用于评估regression的模型的好坏 判断方差的好坏
# Out:
# <Container object of 3 artists>

# %%
def f(x, y):
    return (1 - x / 2 + x**2 + y ** 5) * np.exp(-x**2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X,Y = np.meshgrid(x, y)  # ???? means

plt.contourf(X, Y, f(X,Y), 8, alpha = .75, cmap = plt.cm.hot) # 8 分了8个等级 alpha透明度  cmap图的格式

# %%
plt.imshow(f(X,Y))

# %%
from mpl_toolkits.mplot3d import Axes3D

flg = plt.figure()
ax = Axes3D(flg)
X = np.arange( -3, 3, 0.25)
Y = np.arange( -3, 3, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y **2)
Z= np.sin(R)

ax.plot_surface(X, Y, Z, rstride = 1, cstride = 1, cmap = "hot")
plt.show()

# %%
def update(frame):
    global P, C, S

    # Every ring is made more transparent
    C[:,3] = np.maximum(0, C[:,3] - 1.0/n)

    # Each ring is made larger
    S += (size_max - size_min) / n

    # Reset ring specific ring (relative to frame number)
    i = frame % 50
    P[i] = np.random.uniform(0,1,2)
    S[i] = size_min
    C[i,3] = 1

    # Update scatter object
    scat.set_edgecolors(C)
    scat.set_sizes(S)
    scat.set_offsets(P)

    # Return the modified object
    return scat,

# %matplotlib notebook
from matplotlib.animation import FuncAnimation


fig = plt.figure(figsize=(6,6), facecolor='white')
ax = fig.add_axes([0,0,1,1], frameon=False, aspect=1)

n = 50
size_min = 50
size_max = 50*50

# Ring position
P = np.random.uniform(0,1,(n,2))

# Ring colors
C = np.ones((n,4)) * (0,0,0,1)
# Alpha color channel goes from 0 (transparent) to 1 (opaque)
C[:,3] = np.linspace(0,1,n)

# Ring sizes
S = np.linspace(size_min, size_max, n)

# Scatter plot
scat = ax.scatter(P[:,0], P[:,1], s=S, lw = 0.5,
                  edgecolors = C, facecolors='None')

# Ensure limits are [0,1] and remove ticks
ax.set_xlim(0,1), ax.set_xticks([])
ax.set_ylim(0,1), ax.set_yticks([])
animation = FuncAnimation(fig, update, interval=10, blit=True, frames=200)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

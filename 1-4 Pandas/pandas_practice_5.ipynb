# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
df = pd.read_csv("data.txt", sep = " ")

# %%
df.head()
# Out:
#            instance_id              item_id  \
# 0   108641074714126964  3412720377098676069
# 1  5754713551599725161  3412720377098676069
# 2   842679481291040981  3412720377098676069
# 3   937088850059189027  3412720377098676069
# 4  7975697065017708072  3412720377098676069
#
#                         item_category_list  \
# 0  7908382889764677758;5799347067982556520
# 1  7908382889764677758;5799347067982556520
# 2  7908382889764677758;5799347067982556520
# 3  7908382889764677758;5799347067982556520
# 4  7908382889764677758;5799347067982556520
#
#                                   item_property_list        item_brand_id  \
# 0  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 1  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 2  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 3  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# ...

# %%
#.找出 与 is_trade 相关性最高的前3个字段，并理解下这些高相关性字段代表的含义   【容易】


df.corr()["is_trade"].sort_values(ascending = False)
# Out:
# is_trade                     1.000000
# item_sales_level             0.037358
# item_collected_level         0.013972
# user_gender_id               0.008843
# item_pv_level                0.006077
# user_age_level               0.002628
# user_star_level              0.002239
# user_occupation_id           0.002026
# user_id                      0.000255
# item_id                     -0.000168
# shop_star_level             -0.000735
# shop_review_num_level       -0.000747
# instance_id                 -0.002158
# shop_id                     -0.003238
# context_id                  -0.003459
# item_brand_id               -0.005311
# context_timestamp           -0.009274
# context_page_id             -0.012313
# item_city_id                -0.014622
# shop_score_service          -0.015578
# shop_score_delivery         -0.016239
# shop_score_description      -0.016734
# shop_review_positive_rate   -0.017355
# item_price_level            -0.055895
# Name: is_trade, dtype: float64

# %%
#Answer: item_price_level            -0.055895 负相关
#        item_sales_level             0.037358 正相关
#        shop_review_positive_rate   -0.017355 负相关

# %%
#新增一列，表示item_id最近三天的历史转化率  提示：先把context_timestamp 转换成 日期 【较难】

# %%
df["formatted_context_timestamp"] =df["context_timestamp"].apply(lambda x: datetime.fromtimestamp(x).date())

# %%
df.head()
# Out:
#            instance_id              item_id  \
# 0   108641074714126964  3412720377098676069
# 1  5754713551599725161  3412720377098676069
# 2   842679481291040981  3412720377098676069
# 3   937088850059189027  3412720377098676069
# 4  7975697065017708072  3412720377098676069
#
#                         item_category_list  \
# 0  7908382889764677758;5799347067982556520
# 1  7908382889764677758;5799347067982556520
# 2  7908382889764677758;5799347067982556520
# 3  7908382889764677758;5799347067982556520
# 4  7908382889764677758;5799347067982556520
#
#                                   item_property_list        item_brand_id  \
# 0  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 1  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 2  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 3  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# ...

# %%
df["formatted_context_timestamp"].unique()
# Out:
# array([datetime.date(2018, 9, 17), datetime.date(2018, 9, 18),
#        datetime.date(2018, 9, 20), datetime.date(2018, 9, 21),
#        datetime.date(2018, 9, 19), datetime.date(2018, 9, 22),
#        datetime.date(2018, 9, 23), datetime.date(2018, 9, 24)],
#       dtype=object)
